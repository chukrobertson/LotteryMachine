# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 15]

# %%
df = pd.read_csv("WinningNumberArchive_2019.csv")

# %%
df.shape
# Out:
# (730, 11)

# %%
df.head()
# Out:
#   Day - Draw       Date   Pick 3   Pick 4   Pick 5  \
# 0  TUE - MID   1/1/2019      444     4225    89512
# 1  TUE - EVE   1/1/2019      485     2838    83630
# 2  WED - MID   1/2/2019      103     7637    93755
# 3  WED - EVE   1/2/2019      485      497    55918
# 4  THU - MID   1/3/2019      309     4961    99736
#
#                   Classic Lotto   Kicker              Rolling Cash 5  \
# 0
# 1                                           8 12 14 26 27 $120000.00
# 2
# 3   15 21 24 25 30 40 $8.60 M/0   146233   10 12 18 21 23 $130000.00
# 4
#
#                         Mega Millions                         Powerball  \
# 0
# 1   34 44 57 62 70 +14 x4 $425.00 M/1
# 2
# 3                                       8 12 42 46 56 +12 x2 $53.00 M/0
# 4
#
#    Lucky For Life
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df.tail()
# Out:
#     Day - Draw         Date   Pick 3   Pick 4   Pick 5  \
# 725  SUN - EVE   12/29/2019      219     4498    98235
# 726  MON - MID   12/30/2019      354     5378    24254
# 727  MON - EVE   12/30/2019      655     4842    56307
# 728  TUE - MID   12/31/2019      699     7952    47896
# 729  TUE - EVE   12/31/2019      257     1734    88768
#
#                   Classic Lotto   Kicker              Rolling Cash 5  \
# 725                                        10 14 19 36 37 $260000.00
# 726
# 727   1 8 15 18 40 42 $7.60 M/0   680546    7 11 26 29 36 $306000.00
# 728
# 729                                          7 8 18 23 37 $355000.00
#
#                          Mega Millions  Powerball      Lucky For Life
# 725                                                               NaN
# 726                                                               NaN
# 727                                                4 15 34 40 47 +160
# 728                                                               NaN
# 729   30 44 49 53 56 +11 x3 $55.00 M/0                            NaN

# %%
df.columns
# Out:
# Index(['Day - Draw', ' Date', ' Pick 3', ' Pick 4', ' Pick 5',
#        ' Classic Lotto', ' Kicker', ' Rolling Cash 5', ' Mega Millions',
#        ' Powerball', ' Lucky For Life'],
#       dtype='object')

# %%
df.columns = ['Day_Draw', 'Date', 'Pick3', 'Pick4', 'Pick5', 'Classic_Lotto', 'Kicker', 'Rolling_Cash_5', 'Mega_Millions', 'Powerball', 'Lucky_For_Life']

# %%
df.columns
# Out:
# Index(['Day_Draw', 'Date', 'Pick3', 'Pick4', 'Pick5', 'Classic_Lotto',
#        'Kicker', 'Rolling_Cash_5', 'Mega_Millions', 'Powerball',
#        'Lucky_For_Life'],
#       dtype='object')

# %%
df['Pick3'].value_counts().max()
# Out:
# 6

# %%
df['Pick3'].value_counts().idxmax()
# Out:
# 48

# %%
df.plot.area('Date','Pick3');

# %%
df.Pick3.hist(bins=1000);
